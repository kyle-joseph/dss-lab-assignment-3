# %% [markdown]
# # **Group 5**

# %%
import pandas as pd
import numpy as np
import statistics
import scipy as sc

# %% [markdown]
# ## **Kim Rexell Laviña: Activity 1:** Briefly discuss your respective dataset. Provide the source of your dataset too.

# %% [markdown]
# ## **Kenneth Popera: Activity 2:** Perform loading / reading your group’s dataset
#
# Loading the dataset requires the pandas library which is used for reading, writing and manipulating data. In order to load the csv file of our dataset read_csv() method is used to read the contents of the csv file.

# %%
dataset = pd.read_csv('breast_cancer_wisconsin_csv.csv', index_col = False, names = ['id', 'clump_thickness', 'cell_size_uniformity', 'cell_shape_uniformity', 'marginal_adhesion', 'single_epithelial_cell_size', 'bare_nuclei', 'bland_chromatin', 'normal_nucleoli', 'mitoses', 'class'])
dataset
# Out:
#           id  clump_thickness  cell_size_uniformity  cell_shape_uniformity  \
# 0    1000025                5                     1                      1
# 1    1002945                5                     4                      4
# 2    1015425                3                     1                      1
# 3    1016277                6                     8                      8
# 4    1017023                4                     1                      1
# ..       ...              ...                   ...                    ...
# 694   776715                3                     1                      1
# 695   841769                2                     1                      1
# 696   888820                5                    10                     10
# 697   897471                4                     8                      6
# 698   897471                4                     8                      8
#
#      marginal_adhesion  single_epithelial_cell_size bare_nuclei  \
# ...

# %% [markdown]
# ## **Marben Vilaflor: Activity 3:**  Identify the shape of your data and discuss
#
# Getting the shape of our dataset will use the numpy library. First, you need to convert the dataset into numpy array and print the shape of the dataset using shape() method of numpy library. There are 699 rows and 11 columns in our dataset.

# %%
data_shape = np.array(dataset)
print(np.shape(data_shape))
# Out:
# (699, 11)

# %% [markdown]
# ## **Kyle Joseph Timajo: Activity 4:** Enlist the column names in your dataset and provide the type of data
#
# The Wisconsin Breast Cancer Dataset column names are:
#    1. id number
#    2. Clump Thickness               1 - 10
#    3. Uniformity of Cell Size       1 - 10
#    4. Uniformity of Cell Shape      1 - 10
#    5. Marginal Adhesion             1 - 10
#    6. Single Epithelial Cell Size   1 - 10
#    7. Bare Nuclei                   1 - 10
#    8. Bland Chromatin               1 - 10
#    9. Normal Nucleoli               1 - 10
#   10. Mitoses                       1 - 10
#   11. Class:                        (2 for benign, 4 for malignant)
#
# All of the columns except id number and class has range of values from 1 to 10. The class has a value of either 2 (benign) or 4 (malignant). The id number composed of random numbers. To display all the columns we used the keys() method from pandas. Then, for the data types is we used dtypes.

# %%
columns = dataset.keys()
print(columns)

data_types = dataset.dtypes
print(data_types)
# Out:
# Index(['id', 'clump_thickness', 'cell_size_uniformity',
#        'cell_shape_uniformity', 'marginal_adhesion',
#        'single_epithelial_cell_size', 'bare_nuclei', 'bland_chromatin',
#        'normal_nucleoli', 'mitoses', 'class'],
#       dtype='object')
# id                              int64
# clump_thickness                 int64
# cell_size_uniformity            int64
# cell_shape_uniformity           int64
# marginal_adhesion               int64
# single_epithelial_cell_size     int64
# bare_nuclei                    object
# bland_chromatin                 int64
# normal_nucleoli                 int64
# mitoses                         int64
# class                           int64
# dtype: object

# %% [markdown]
# ## **Kim Rexell Laviña: Activity 5:** Provide a sample view of your dataset

# %%
dataset
# Out:
#           id  clump_thickness  cell_size_uniformity  cell_shape_uniformity  \
# 0    1000025                5                     1                      1
# 1    1002945                5                     4                      4
# 2    1015425                3                     1                      1
# 3    1016277                6                     8                      8
# 4    1017023                4                     1                      1
# ..       ...              ...                   ...                    ...
# 694   776715                3                     1                      1
# 695   841769                2                     1                      1
# 696   888820                5                    10                     10
# 697   897471                4                     8                      6
# 698   897471                4                     8                      8
#
#      marginal_adhesion  single_epithelial_cell_size bare_nuclei  \
# ...

# %% [markdown]
# ## **Kenneth Popera: Activity 6:** Provide a sample view of some dirty data in your dataset. i.e missing values or unusual values in your dataset. You may count the number of rows that contains missing values.
#
# As provided in the dataset there are 16 missing values and it is denoted by question mark "?". All of the missing values are in the bare_nuclei column.

# %%
dataset.head(42)
# Out:
#          id  clump_thickness  cell_size_uniformity  cell_shape_uniformity  \
# 0   1000025                5                     1                      1
# 1   1002945                5                     4                      4
# 2   1015425                3                     1                      1
# 3   1016277                6                     8                      8
# 4   1017023                4                     1                      1
# 5   1017122                8                    10                     10
# 6   1018099                1                     1                      1
# 7   1018561                2                     1                      2
# 8   1033078                2                     1                      1
# 9   1033078                4                     2                      1
# 10  1035283                1                     1                      1
# 11  1036172                2                     1                      1
# ...

# %% [markdown]
# ## **Marben Villaflor: Activity 7:** Perform data cleaning and provide a screenshot of both the dirty data (in 5.) and a clean data.
#
# In cleaning the dataset, we remove all the rows that contains "?". From 699 rows, it became 683 rows after cleaning. To remove all the rows with question marks, we loop through all the rows and check each value of the the bare_nuclei column and drop the row using the drop() method of pandas.

# %%
for x in dataset.index:
  if dataset.loc[x, "bare_nuclei"] == "?":
    dataset.drop(x, inplace = True)

# %%
dataset
# Out:
#           id  clump_thickness  cell_size_uniformity  cell_shape_uniformity  \
# 0    1000025                5                     1                      1
# 1    1002945                5                     4                      4
# 2    1015425                3                     1                      1
# 3    1016277                6                     8                      8
# 4    1017023                4                     1                      1
# ..       ...              ...                   ...                    ...
# 694   776715                3                     1                      1
# 695   841769                2                     1                      1
# 696   888820                5                    10                     10
# 697   897471                4                     8                      6
# 698   897471                4                     8                      8
#
#      marginal_adhesion  single_epithelial_cell_size bare_nuclei  \
# ...

# %% [markdown]
# ## **Kyle Joseph Timajo: Activity 8:** Compute the mean, media, mode, standard deviation, variance, ranges and percentiles of your dataset. Identify possible outliers.

# %% [markdown]
# ## **Getting the Mean**

# %%
#since 1 column (bare_nuclei) is in object data type then, we will convert it into int64 in order to get the mean.
dataset['bare_nuclei'] = pd.to_numeric(dataset['bare_nuclei'])

#mean
mean = np.mean(dataset)
print(mean)
# Out:
# id                             1.076720e+06
# clump_thickness                4.442167e+00
# cell_size_uniformity           3.150805e+00
# cell_shape_uniformity          3.215227e+00
# marginal_adhesion              2.830161e+00
# single_epithelial_cell_size    3.234261e+00
# bare_nuclei                    3.544656e+00
# bland_chromatin                3.445095e+00
# normal_nucleoli                2.869693e+00
# mitoses                        1.603221e+00
# class                          2.699854e+00
# dtype: float64

# %% [markdown]
# ## **Getting the Median**

# %%
for key in dataset:
    median = np.median(dataset[key])
    print("%s: %s" % (key, median))
# Out:
# id: 1171795.0
# clump_thickness: 4.0
# cell_size_uniformity: 1.0
# cell_shape_uniformity: 1.0
# marginal_adhesion: 1.0
# single_epithelial_cell_size: 2.0
# bare_nuclei: 1.0
# bland_chromatin: 3.0
# normal_nucleoli: 1.0
# mitoses: 1.0
# class: 2.0

# %% [markdown]
# ## **Getting the Mode**

# %%
for key in dataset:
    mode = statistics.mode(dataset[key])
    print("%s: %s" % (key, mode))
# Out:
# id: 1182404
# clump_thickness: 1
# cell_size_uniformity: 1
# cell_shape_uniformity: 1
# marginal_adhesion: 1
# single_epithelial_cell_size: 2
# bare_nuclei: 1
# bland_chromatin: 3
# normal_nucleoli: 1
# mitoses: 1
# class: 2

# %% [markdown]
# ## **Getting the Variance**

# %%
variance = np.var(dataset, ddof=1)
variance
# Out:
# id                             3.851990e+11
# clump_thickness                7.956694e+00
# cell_size_uniformity           9.395113e+00
# cell_shape_uniformity          8.931615e+00
# marginal_adhesion              8.205717e+00
# single_epithelial_cell_size    4.942109e+00
# bare_nuclei                    1.327770e+01
# bland_chromatin                6.001013e+00
# normal_nucleoli                9.318772e+00
# mitoses                        3.002160e+00
# class                          9.112463e-01
# dtype: float64

# %% [markdown]
# ## **Getting the Standard Deviation**

# %%
standard_deviation = np.std(dataset, ddof=1)
standard_deviation
# Out:
# id                             620644.047655
# clump_thickness                     2.820761
# cell_size_uniformity                3.065145
# cell_shape_uniformity               2.988581
# marginal_adhesion                   2.864562
# single_epithelial_cell_size         2.223085
# bare_nuclei                         3.643857
# bland_chromatin                     2.449697
# normal_nucleoli                     3.052666
# mitoses                             1.732674
# class                               0.954592
# dtype: float64

# %% [markdown]
# ## **Getting the Percentiles**

# %%
for key in dataset:
    percentile = np.percentile(dataset[key], [25, 50, 75])
    print("%s: %s" % (key, percentile))
# Out:
# id: [ 877617. 1171795. 1238705.]
# clump_thickness: [2. 4. 6.]
# cell_size_uniformity: [1. 1. 5.]
# cell_shape_uniformity: [1. 1. 5.]
# marginal_adhesion: [1. 1. 4.]
# single_epithelial_cell_size: [2. 2. 4.]
# bare_nuclei: [1. 1. 6.]
# bland_chromatin: [2. 3. 5.]
# normal_nucleoli: [1. 1. 4.]
# mitoses: [1. 1. 1.]
# class: [2. 2. 4.]

# %% [markdown]
# ## **Getting the Ranges**

# %%
for key in dataset:
    ranges = np.ptp(dataset[key])
    print("%s: %s" % (key, ranges))
# Out:
# id: 13390977
# clump_thickness: 9
# cell_size_uniformity: 9
# cell_shape_uniformity: 9
# marginal_adhesion: 9
# single_epithelial_cell_size: 9
# bare_nuclei: 9
# bland_chromatin: 9
# normal_nucleoli: 9
# mitoses: 9
# class: 2

# %% [markdown]
# ## **All Members: Activity 9:** Provide the following basic visualization technique of your dataset. (a) Box Plot (b) Histogram.

# %% [markdown]
# ## **Box Plot**

# %%
import matplotlib.pyplot as plt

plt.boxplot([dataset['clump_thickness'], dataset['cell_size_uniformity'],
dataset['cell_shape_uniformity'], dataset['marginal_adhesion'],
dataset['single_epithelial_cell_size'], dataset['bare_nuclei'], 
dataset['bland_chromatin'], dataset['normal_nucleoli'], 
dataset['mitoses'], dataset['class']])
plt.show()
